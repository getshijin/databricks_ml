# %%
#pip install nltk

# %%
corpus = """ hello Welcome to shijin project. he is a great teacher. i love to learn from him. 
thank you shijin project """

# %%
import nltk
#nltk.download('punkt', force=True)
#nltk.download('punkt_tab', force=True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\getsh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\getsh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
#nltk.data.path.append(r"C:\Users\getsh\AppData\Roaming\nltk_data\tokenizers\punkt")

# %%
## Tokenization
## Sentence -> paragraph
from nltk.tokenize import sent_tokenize

# %%
documents =sent_tokenize(corpus)

# %%
## tokenize sentence into words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['hello',
#  'Welcome',
#  'to',
#  'shijin',
#  'project',
#  '.',
#  'he',
#  'is',
#  'a',
#  'great',
#  'teacher',
#  '.',
#  'i',
#  'love',
#  'to',
#  'learn',
#  'from',
#  'him',
#  '.',
#  'thank',
#  'you',
#  'shijin',
#  'project']

# %%
### tokenize with punctuation preserved
from nltk.tokenize import TreebankWordTokenizer, WordPunctTokenizer

# %%
TreebankWordTokenizer().tokenize(corpus)
# Out:
# ['hello',
#  'Welcome',
#  'to',
#  'shijin',
#  'project.',
#  'he',
#  'is',
#  'a',
#  'great',
#  'teacher.',
#  'i',
#  'love',
#  'to',
#  'learn',
#  'from',
#  'him.',
#  'thank',
#  'you',
#  'shijin',
#  'project']
